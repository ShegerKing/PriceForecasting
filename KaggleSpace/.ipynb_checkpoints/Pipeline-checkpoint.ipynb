# %%
#import all the necessary data
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# First let us import all the necessary files

# %%
transactions = pd.read_csv("sales_train.csv.gz")
catagories = pd.read_csv("item_categories.csv")
shopes = pd.read_csv("shops.csv")
sample = pd.read_csv("sample_submission.csv.gz")
products = pd.read_csv("items.csv")

# %%
transactions.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0 2013-01-02               0       59    22154      999.00           1.0
# 1 2013-01-03               0       25     2552      899.00           1.0
# 2 2013-01-05               0       25     2552      899.00          -1.0
# 3 2013-01-06               0       25     2554     1709.05           1.0
# 4 2013-01-15               0       25     2555     1099.00           1.0

# %%
transactions["date"] = pd.to_datetime(transactions.date, format = '%d.%m.%Y')

# %%
A  = transactions.groupby([transactions.date.dt.year, transactions.date.dt.month], as_index = False)[["item_cnt_day"]].count()

# %%
plt.plot(A)

# %%
plt.plot(transactions[transactions["shop_id"] == 21].groupby(
    [transactions.date.dt.year, transactions.date.dt.month], as_index= False)[["item_cnt_day"]].count(), 'r')

# %%
plt.boxplot((transactions["item_price"]))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10f7ff50>,
#   <matplotlib.lines.Line2D at 0x10f7fd30>],
#  'caps': [<matplotlib.lines.Line2D at 0x10f7f6b0>,
#   <matplotlib.lines.Line2D at 0x10fce2d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x10f7f790>],
#  'medians': [<matplotlib.lines.Line2D at 0x10fce550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10fce750>],
#  'means': []}

# %%
plt.boxplot(transactions["item_price"].apply(lambda x : x/10000))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11009990>,
#   <matplotlib.lines.Line2D at 0x11009b90>],
#  'caps': [<matplotlib.lines.Line2D at 0x11009df0>,
#   <matplotlib.lines.Line2D at 0x11009f10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x110096f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1101e350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1101e550>],
#  'means': []}
